# %%
import pandas as pd
weather  = pd.read_csv('climate_data.csv',index_col='DATE')

# %%
weather
# Out:
#                 STATION                                  NAME  ACMH  ACSH  \
# DATE
# 1960-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# ...                 ...                                   ...   ...   ...
# 2022-02-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-02-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-02-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-02-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-02-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
#
# ...

# %%
weather.loc["1960-01-01":"1960-01-31",:] #reading the data for certain days
# Out:
#                 STATION                                  NAME  ACMH  ACSH  \
# DATE
# 1960-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-06  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-07  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-08  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-09  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-10  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-11  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-12  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# ...

# %%
weather.isna().sum()/weather.shape[0] # finding the null values in the dataset
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.653545
# ACSH       0.653545
# AWND       0.522113
# DAPR       0.999526
# FMTM       0.870168
# FRGT       0.999881
# MDPR       0.999526
# PGTM       0.495435
# PRCP       0.016659
# SNOW       0.325350
# SNWD       0.317999
# TAVG       0.879239
# TMAX       0.000534
# TMIN       0.000593
# TSUN       0.931764
# WDF1       0.653545
# WDF2       0.522054
# WDF5       0.527211
# WDFG       0.747036
# WSF1       0.653545
# WSF2       0.521994
# WSF5       0.527211
# WSFG       0.747036
# WT01       0.779701
# WT02       0.980258
# WT03       0.992945
# WT04       0.999763
# WT05       0.998340
# WT07       0.999881
# WT08       0.810292
# WT09       0.999881
# WT16       0.884100
# WT18       0.999822
# dtype: float64

# %%
core_weather  = weather[["PRCP","SNOW","SNWD","TMAX","TMIN"]].copy() # taking the main parts of the weather as another copy

# %%
core_weather.columns = ["precip","snow","snow_depth","temp_max","temp_min"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1960-01-01     0.0   0.0         0.0      49.0      30.0
# 1960-01-02     0.0   0.0         0.0      49.0      29.0
# 1960-01-03     0.0   0.0         0.0      54.0      35.0
# 1960-01-04     0.0   0.0         0.0      54.0      36.0
# 1960-01-05     0.0   0.0         0.0      55.0      33.0
# ...            ...   ...         ...       ...       ...
# 2022-02-01     0.0   NaN         NaN      63.0      39.0
# 2022-02-02     0.0   NaN         NaN      64.0      43.0
# 2022-02-03     0.0   NaN         NaN      60.0      37.0
# 2022-02-04     0.0   NaN         NaN      62.0      38.0
# 2022-02-05     0.0   NaN         NaN      63.0      39.0
#
# [16868 rows x 5 columns]

# %%
#filling the missing_values
core_weather.isna().sum()/core_weather.shape[0]
# Out:
# precip        0.016659
# snow          0.325350
# snow_depth    0.317999
# temp_max      0.000534
# temp_min      0.000593
# dtype: float64

# %%
core_weather["snow"].value_counts()
# Out:
# 0.0    11379
# 1.0        1
# Name: snow, dtype: int64

# %%
del core_weather["snow"]

# %%
core_weather["snow_depth"].value_counts()
# Out:
# 0.0    11504
# Name: snow_depth, dtype: int64

# %%
del core_weather["snow_depth"]

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1983-10-29     NaN      67.0      57.0
# 1983-10-30     NaN      70.0      63.0
# 1983-10-31     NaN      69.0      61.0
# 1983-11-12     NaN      63.0      55.0
# 1983-11-13     NaN      60.0      50.0
# ...            ...       ...       ...
# 2013-12-15     NaN      58.0      33.0
# 2016-05-01     NaN      80.0      55.0
# 2016-05-02     NaN      68.0      53.0
# 2016-05-08     NaN      67.0      56.0
# 2017-10-28     NaN      68.0      50.0
#
# [281 rows x 3 columns]

# %%
core_weather.loc["1983-10-20":"1983-11-05",:]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1983-10-20    0.00      73.0      52.0
# 1983-10-21    0.00      70.0      50.0
# 1983-10-22    0.00      70.0      50.0
# 1983-10-23    0.00      69.0      60.0
# 1983-10-24    0.00      73.0      58.0
# 1983-10-25    0.00      75.0      53.0
# 1983-10-26    0.00      79.0      53.0
# 1983-10-27    0.00      82.0      56.0
# 1983-10-28    0.00      74.0      56.0
# 1983-10-29     NaN      67.0      57.0
# 1983-10-30     NaN      70.0      63.0
# 1983-10-31     NaN      69.0      61.0
# 1983-11-01    0.26      69.0      60.0
# 1983-11-02    0.06      68.0      56.0
# 1983-11-03    0.00      68.0      56.0
# 1983-11-04    0.00      67.0      55.0
# 1983-11-05    0.00      66.0      51.0

# %%
core_weather["precip"].value_counts()
# Out:
# 0.00    13673
# 0.01      438
# 0.02      199
# 0.03      122
# 0.04      102
#         ...
# 1.29        1
# 1.73        1
# 1.05        1
# 1.38        1
# 1.02        1
# Name: precip, Length: 176, dtype: int64

# %%
core_weather["precip"] = core_weather["precip"].fillna(0) # fillin the NA with 0

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2004-11-20     0.0       NaN       NaN
# 2011-12-21     0.0      61.0       NaN
# 2011-12-22     0.0      62.0       NaN
# 2011-12-23     0.0      56.0       NaN
# 2011-12-24     0.0      55.0       NaN
# 2011-12-25     0.0      54.0       NaN
# 2013-06-16     0.0       NaN       NaN
# 2020-08-29     0.0       NaN       NaN
# 2020-09-08     0.0       NaN       NaN
# 2020-09-09     0.0       NaN       NaN

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2004-11-20     0.0       NaN       NaN
# 2011-12-21     0.0      61.0       NaN
# 2011-12-22     0.0      62.0       NaN
# 2011-12-23     0.0      56.0       NaN
# 2011-12-24     0.0      55.0       NaN
# 2011-12-25     0.0      54.0       NaN
# 2013-06-16     0.0       NaN       NaN
# 2020-08-29     0.0       NaN       NaN
# 2020-09-08     0.0       NaN       NaN
# 2020-09-09     0.0       NaN       NaN

# %%
core_weather = core_weather.fillna(method="ffill") # this is a method 
#where the null values is filled by the previous not null values

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip      0.0
# temp_max    0.0
# temp_min    0.0
# dtype: float64

# %%
core_weather.dtypes
# Out:
# precip      float64
# temp_max    float64
# temp_min    float64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04', '1960-01-05',
#        '1960-01-06', '1960-01-07', '1960-01-08', '1960-01-09', '1960-01-10',
#        ...
#        '2022-01-27', '2022-01-28', '2022-01-29', '2022-01-30', '2022-01-31',
#        '2022-02-01', '2022-02-02', '2022-02-03', '2022-02-04', '2022-02-05'],
#       dtype='object', name='DATE', length=16868)

# %%
core_weather.index = pd.to_datetime(core_weather.index) #converting index objects to
# to datetime

# %%
core_weather.index
# Out:
# DatetimeIndex(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04',
#                '1960-01-05', '1960-01-06', '1960-01-07', '1960-01-08',
#                '1960-01-09', '1960-01-10',
#                ...
#                '2022-01-27', '2022-01-28', '2022-01-29', '2022-01-30',
#                '2022-01-31', '2022-02-01', '2022-02-02', '2022-02-03',
#                '2022-02-04', '2022-02-05'],
#               dtype='datetime64[ns]', name='DATE', length=16868, freq=None)

# %%
core_weather.apply(lambda x: (x==9999).sum())# by seeing the data document this 9999 indicates the missing values
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
core_weather[["temp_max","temp_min"]].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather.index.year.value_counts().sort_index()
# Out:
# 1960    366
# 1961    365
# 1962    365
# 1963    365
# 1964    366
# 1965    365
# 1966    365
# 1967    365
# 1968    366
# 1969    365
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1983    184
# 1984    366
# 1985    365
# 1986    212
# 2000    365
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    365
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022     36
# Name: DATE, dtype: int64

# %%
core_weather["precip"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).sum()["precip"]
# Out:
# DATE
# 1960    14.01
# 1961    13.87
# 1962    22.47
# 1963    19.11
# 1964    16.83
# 1965    16.32
# 1966    13.11
# 1967    23.98
# 1968    17.19
# 1969    25.70
# 1970    25.31
# 1971    10.61
# 1972    16.27
# 1973    29.37
# 1974    16.87
# 1975    17.54
# 1976     8.64
# 1977    11.70
# 1978    22.57
# 1979    23.79
# 1980    13.58
# 1983     7.13
# 1984    16.03
# 1985     8.50
# 1986     0.00
# 2000    21.09
# 2001    22.84
# 2002    19.12
# 2003    11.37
# 2004    12.97
# 2005    27.37
# 2006    22.79
# 2007    12.79
# 2008    13.86
# 2009    14.57
# 2010    22.67
# 2011    16.06
# 2012    22.93
# 2013     4.89
# 2014    19.62
# 2015     8.58
# 2016    19.77
# 2017    23.34
# 2018    16.82
# 2019    20.00
# 2020     6.42
# 2021    20.82
# 2022     0.25
# Name: precip, dtype: float64

# %%
core_weather["target"] = core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-01-01     0.0      49.0      30.0    49.0
# 1960-01-02     0.0      49.0      29.0    54.0
# 1960-01-03     0.0      54.0      35.0    54.0
# 1960-01-04     0.0      54.0      36.0    55.0
# 1960-01-05     0.0      55.0      33.0    53.0
# ...            ...       ...       ...     ...
# 2022-02-01     0.0      63.0      39.0    64.0
# 2022-02-02     0.0      64.0      43.0    60.0
# 2022-02-03     0.0      60.0      37.0    62.0
# 2022-02-04     0.0      62.0      38.0    63.0
# 2022-02-05     0.0      63.0      39.0     NaN
#
# [16868 rows x 4 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-01-01     0.0      49.0      30.0    49.0
# 1960-01-02     0.0      49.0      29.0    54.0
# 1960-01-03     0.0      54.0      35.0    54.0
# 1960-01-04     0.0      54.0      36.0    55.0
# 1960-01-05     0.0      55.0      33.0    53.0
# ...            ...       ...       ...     ...
# 2022-01-31     0.0      58.0      43.0    63.0
# 2022-02-01     0.0      63.0      39.0    64.0
# 2022-02-02     0.0      64.0      43.0    60.0
# 2022-02-03     0.0      60.0      37.0    62.0
# 2022-02-04     0.0      62.0      38.0    63.0
#
# [16867 rows x 4 columns]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
predictors = ["precip","temp_max","temp_min"]

# %%
train = core_weather.loc[:"2020-12-31"]

# %%
test = core_weather.loc["2020-01-01":]

# %%
reg.fit(train[predictors],train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test["target"], predictions)
# Out:
# 3.523638685023198

# %%
combined = pd.concat([test["target"],pd.Series(predictions, index = test.index)], axis=1)
#for combining the predicted and original data
combined.columns = ["actual","predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2020-01-01    60.0    59.983338
# 2020-01-02    61.0    60.165405
# 2020-01-03    61.0    60.527162
# 2020-01-04    60.0    61.223851
# 2020-01-05    58.0    59.446643
# ...            ...          ...
# 2022-01-31    63.0    58.902819
# 2022-02-01    64.0    61.789748
# 2022-02-02    60.0    63.229649
# 2022-02-03    62.0    59.266952
# 2022-02-04    63.0    60.888920
#
# [766 rows x 2 columns]

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-2.20730384,  0.72113834,  0.17969047])

# %%
core_weather["month_max"] = core_weather["temp_max"].rolling(30).mean()

core_weather["month_day_max"] = core_weather["month_max"] / core_weather["temp_max"]

core_weather["max_min"] = core_weather["temp_max"] / core_weather["temp_min"]

# %%
core_weather = core_weather.iloc[30:,:].copy()

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2020-12-31"]
    test = core_weather.loc["2021-01-01":]

    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])

    error = mean_absolute_error(test["target"], predictions)
    
    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
predictors = ["precip", "temp_max", "temp_min", "month_day_max", "max_min"]

error, combined = create_predictions(predictors, core_weather, reg)
error
# Out:
# 3.3282945722595763

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather["monthly_avg"] = core_weather["temp_max"].groupby(core_weather.index.month).apply(lambda x: x.expanding(1).mean())
core_weather["day_of_year_avg"] = core_weather["temp_max"].groupby(core_weather.index.day_of_year).apply(lambda x: x.expanding(1).mean())

# %%
error, combined = create_predictions(predictors + ["monthly_avg", "day_of_year_avg"], core_weather, reg)
error
# Out:
# 3.2729154341037066

# %%
reg.coef_
# Out:
# array([-1.07706522,  0.69350145,  0.04696919,  4.78060588,  0.07003167,
#         0.16384976,  0.08581002])

# %%
core_weather.corr()["target"]
# Out:
# precip            -0.205311
# temp_max           0.821680
# temp_min           0.596041
# target             1.000000
# month_max          0.686920
# month_day_max     -0.421325
# max_min            0.045151
# monthly_avg        0.689866
# day_of_year_avg    0.712396
# Name: target, dtype: float64

# %%
combined["diff"] = (combined["actual"] - combined["predictions"]).abs()

# %%
combined.sort_values("diff", ascending=False).head(10)
# Out:
#             actual  predictions       diff
# DATE
# 2021-01-17    83.0    68.433744  14.566256
# 2021-04-01    62.0    75.713379  13.713379
# 2021-05-07    81.0    67.678091  13.321909
# 2021-02-21    77.0    64.141065  12.858935
# 2021-10-16    66.0    78.707594  12.707594
# 2021-02-22    84.0    71.354231  12.645769
# 2021-03-30    82.0    69.994973  12.005027
# 2021-07-07    79.0    67.323738  11.676262
# 2021-03-29    74.0    62.502014  11.497986
# 2021-10-04    69.0    80.384267  11.384267
